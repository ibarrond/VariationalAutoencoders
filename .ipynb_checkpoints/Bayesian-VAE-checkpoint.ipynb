# %%
import numpy as np
import time
import gc

# %%
from models.bayesian_vae import BayesianVAE
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
VA = BayesianVAE(
                 n_inputs=784,
                 n_neurons_encoder = [256, 128],
                 n_latent=2,
                 n_neurons_decoder = [128, 256],
                 batch_size = 128)

VA.learn(epochs=100, learning_rate=0.01)
# Out:
#    [10.9] Epoch: 01 | NELBO: 4595.647072 | ELL: -4595.535294 | KL: 0.111786 | Val. NELBO: 4543.377429
#    [10.5] Epoch: 02 | NELBO: 4435.764577 | ELL: -4435.673768 | KL: 0.090807 | Val. NELBO: 4349.535895
#    [10.6] Epoch: 03 | NELBO: 4276.399362 | ELL: -4276.308004 | KL: 0.091359 | Val. NELBO: 4189.194123

# %%
VA.plot_enc_dec(10)
