# %%
import numpy as np
import time
import gc

# %%
from models.bayesian_autoencoder import BayesianAutoencoder
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# including input neurons
mc_samples_train = 1
batch_size = 128
epochs = 100

# %%
neurons_per_layer = [784, 32, 784]
vi = BayesianAutoencoder(neurons_per_layer, batch_size, constant_prior=False)
vi.learn(learning_rate=0.01, epochs=epochs)
print('Test Log-Likelihood: %.6f' % vi.benchmark())
# Out:
#    [6.0] Epoch: 01 | NELBO: 37072706.550117 | ELL: -674.049210 | KL: 0.655987 | Val. NELBO: 26168717.025641
#    [5.9] Epoch: 02 | NELBO: 21869217.379953 | ELL: -397.622134 | KL: 0.281949 | Val. NELBO: 18485910.820513
#    [6.0] Epoch: 03 | NELBO: 16377457.487179 | ELL: -297.771954 | KL: 0.234879 | Val. NELBO: 14592858.153846
#    [5.8] Epoch: 04 | NELBO: 13455706.314685 | ELL: -244.649206 | KL: 0.243933 | Val. NELBO: 12325010.307692
#    [5.7] Epoch: 05 | NELBO: 11730464.456876 | ELL: -213.281172 | KL: 0.298791 | Val. NELBO: 11011898.692308
#    [6.3] Epoch: 06 | NELBO: 10608671.331002 | ELL: -192.884933 | KL: 0.370041 | Val. NELBO: 10131766.230769
#    [5.5] Epoch: 07 | NELBO: 9803511.020979 | ELL: -178.245647 | KL: 0.491115 | Val. NELBO: 9379457.717949
#    [5.5] Epoch: 08 | NELBO: 9218669.038462 | ELL: -167.612146 | KL: 0.674723 | Val. NELBO: 8921593.717949
#    [5.5] Epoch: 09 | NELBO: 8803394.693473 | ELL: -160.061704 | KL: 0.940257 | Val. NELBO: 8578168.615385
# ...

# %%
print('Test Log-Likelihood: %.6f' % vi.benchmark())
# Out:
# Test Log-Likelihood: -116.573903

# %%
# n_datapoints, n_layers, neurons_per_layer, mc_samples, batch_size
neurons_per_layer = [784, 256, 128, 2, 128, 256, 784]
vi = BayesianAutoencoder(neurons_per_layer, batch_size, constant_prior=False)
vi.learn(learning_rate=0.01, epochs=epochs)
print('Test Log-Likelihood: %.6f' % vi.benchmark())
# Out:
#    [12.5] Epoch: 01 | NELBO: 2103.265079 | ELL: -2099.546094 | KL: 3.718982 | Val. NELBO: 1105.926557
#    [12.7] Epoch: 02 | NELBO: 1035.597358 | ELL: -1034.228893 | KL: 1.368464 | Val. NELBO: 978.202774
#    [13.0] Epoch: 03 | NELBO: 912.793703 | ELL: -911.274002 | KL: 1.519701 | Val. NELBO: 859.506945
#    [13.8] Epoch: 04 | NELBO: 811.832730 | ELL: -810.193169 | KL: 1.639562 | Val. NELBO: 760.094130
#    [13.6] Epoch: 05 | NELBO: 729.820030 | ELL: -727.991604 | KL: 1.828423 | Val. NELBO: 694.890744
#    [13.6] Epoch: 06 | NELBO: 657.456728 | ELL: -655.330076 | KL: 2.126652 | Val. NELBO: 625.161452
#    [13.5] Epoch: 07 | NELBO: 601.300172 | ELL: -598.663821 | KL: 2.636350 | Val. NELBO: 574.193683
#    [13.5] Epoch: 08 | NELBO: 550.009476 | ELL: -546.976506 | KL: 3.032970 | Val. NELBO: 529.867566
#    [13.5] Epoch: 09 | NELBO: 513.310372 | ELL: -509.302259 | KL: 4.008114 | Val. NELBO: 493.606082
# ...

# %%
# n_datapoints, n_layers, neurons_per_layer, mc_samples, batch_size
neurons_per_layer = [784, 128, 64, 2, 64, 128, 784]
vi = BayesianAutoencoder(neurons_per_layer, batch_size, constant_prior=False)
vi.learn(learning_rate=0.01, epochs=epochs)
print('Test Log-Likelihood: %.6f' % vi.benchmark())
# Out:
#    [12.5] Epoch: 01 | NELBO: 1706.629556 | ELL: -1702.503819 | KL: 4.125738 | Val. NELBO: 922.250393
#    [13.1] Epoch: 02 | NELBO: 820.980638 | ELL: -818.572004 | KL: 2.408634 | Val. NELBO: 738.665122
#    [12.5] Epoch: 03 | NELBO: 675.759903 | ELL: -673.231175 | KL: 2.528729 | Val. NELBO: 624.602512
#    [14.2] Epoch: 04 | NELBO: 577.850030 | ELL: -574.847107 | KL: 3.002921 | Val. NELBO: 539.793280
#    [15.1] Epoch: 05 | NELBO: 507.279908 | ELL: -503.809997 | KL: 3.469910 | Val. NELBO: 479.941007
#    [13.7] Epoch: 06 | NELBO: 453.138921 | ELL: -449.172965 | KL: 3.965956 | Val. NELBO: 431.439682
#    [13.5] Epoch: 07 | NELBO: 410.416492 | ELL: -406.169560 | KL: 4.246932 | Val. NELBO: 391.687881
#    [13.3] Epoch: 08 | NELBO: 376.179261 | ELL: -371.287339 | KL: 4.891921 | Val. NELBO: 363.114484
#    [13.3] Epoch: 09 | NELBO: 350.027199 | ELL: -344.640882 | KL: 5.386317 | Val. NELBO: 336.723548
# ...

# %%
# n_datapoints, n_layers, neurons_per_layer, mc_samples, batch_size
neurons_per_layer = [784, 128, 64, 32, 64, 128, 784]
vi = BayesianAutoencoder(neurons_per_layer, batch_size, constant_prior=False)
vi.learn(learning_rate=0.01, epochs=epochs)
print('Test Log-Likelihood: %.6f' % vi.benchmark())

# %%
vi.serialize('DUMPS/bae-simple/model.ckpt')
# Out:
# Model saved in file: DUMPS/bae-simple/model.ckpt

# %%
neurons_per_layer = [784, 32, 784]

# %%
vi = BayesianAutoencoder(neurons_per_layer, batch_size, constant_prior=False)
vi.restore('DUMPS/bae-simple/model.ckpt')
# Out:
# INFO:tensorflow:Restoring parameters from DUMPS/bae-simple/model.ckpt

# %% [markdown]
# ### Results with [784, 128, 64, 2, 64, 128, 784] architecture and 100 epochs (converged)

# %%
plot_enc_dec()

# %% [markdown]
# ### Results with [784, 128, 64, 32, 64, 128, 784] architecture and 100 epochs (converged)

# %%
plot_enc_dec()

# %%
plot_enc_dec()

# %% [markdown]
# ### Results with [784, 32, 784] architecture and 100 epochs (converged)

# %%
plot_enc_dec()

# %% [markdown]
# ## Bayesian Autoencoder [784, 32, 784]

# %%
vi.plot_enc_dec(10)

# %%
vi.plot_enc_dec(10)

# %% [markdown]
# ## Bayesian Autoencoder [784, 128, 64, 2, 64, 128, 784]

# %%
vi.plot_enc_dec(10)

# %%
vi.plot_enc_dec(10)

# %% [markdown]
# ## Bayesian Autoencoder [784, 128, 64, 32, 64, 128, 784]

# %%
vi.plot_enc_dec(10)

# %%
vi.plot_enc_dec(10)
