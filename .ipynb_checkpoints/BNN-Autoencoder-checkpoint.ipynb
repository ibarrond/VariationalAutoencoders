# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import gc

# %%
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
class VariationalInference(object):
    def __init__(self, n_datapoints, neurons_per_layer, mc_samples, batch_size, constant_prior=False):
        # SIZES
        self.N = n_datapoints
        self.layers = len(neurons_per_layer)
        self.neurons_per_layer = neurons_per_layer
        self.M = batch_size
        ## Set the number of Monte Carlo samples as a placeholder so that it can be different for training and test
        # self.L =  tf.placeholder(tf.int32)
        self.L = mc_samples
        
        self.constant_prior = constant_prior
        
        ## Batch data placeholders
        with tf.name_scope('input'):
            self.X = tf.placeholder(tf.float32, shape=[None, neurons_per_layer[0]], name='x-input')
            self.Y = tf.placeholder(tf.float32, shape=[None, neurons_per_layer[-1]], name='y-input')
            
        with tf.name_scope('input_reshape'):
            image_shaped_input = tf.reshape(self.X, [-1, 28, 28, 1])
            tf.summary.image('input', image_shaped_input, 10)
        
        # PRIOR OF WEIGHTS
        self.prior_mean_W, self.log_prior_var_W = self.get_prior_W()
    
        # POSTERIOR OF WEIGHTS
        self.mean_W, self.log_var_W = self.init_posterior_W()
        ## Builds whole computational graph with relevant quantities as part of the class
        self.loss, self.kl, self.ell = self.get_nelbo()

        ## Initialize the session
        self.session = tf.Session()
    
    def variable_summaries(self, var):
        """Attach a lot of summaries to a Tensor (for TensorBoard visualization)."""
        with tf.name_scope('summaries'):
            mean = tf.reduce_mean(var)
            tf.summary.scalar('mean', mean)
            with tf.name_scope('stddev'):
                stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
                tf.summary.scalar('stddev', stddev)
                tf.summary.scalar('max', tf.reduce_max(var))
                tf.summary.scalar('min', tf.reduce_min(var))
                tf.summary.histogram('histogram', var)

    def get_prior_W(self):
        """
        Define a prior for the weight distribution.
        We assume them to be standard normal iid.
        """
        prior_mean_W = []
        log_prior_var_W = []
        
        for i in range(self.layers - 1):
            d_in = self.neurons_per_layer[i] + 1 # + 1 because of bias weight
            d_out = self.neurons_per_layer[i+1]
            
            with tf.name_scope("layer_" + str(i+1) + "_prior_weights"):
                if self.constant_prior:
                    prior_mean = tf.constant(0.0, shape=[d_in, d_out])
                    log_prior_var = tf.constant(0.0, shape=[d_in, d_out])
                else:
                    prior_mean = tf.Variable(tf.zeros([d_in, d_out]), name="p_W")
                    log_prior_var = tf.Variable(tf.zeros([d_in, d_out]), name="p_W")
                    
                tf.summary.histogram('prior_mean', tf.reshape(prior_mean, [-1]))
                tf.summary.histogram('prior_logvar', tf.reshape(log_prior_var, [-1]))
            
            prior_mean_W.append(prior_mean)
            log_prior_var_W.append(log_prior_var)
        
        return prior_mean_W, log_prior_var_W

    def init_posterior_W(self):
        """
        The (variational) posterior is assumed to be
        drawn from P mutually independent normal distributions.
        Hence, we have a diagonal covariance matrix and only need to store an array.
        """
        mean_W = []
        log_var_W = []
        
        for i in range(self.layers - 1):
            d_in = self.neurons_per_layer[i] + 1 # + 1 because of bias weight
            d_out = self.neurons_per_layer[i+1]

            with tf.name_scope("layer_" + str(i+1) + "_posterior_weights"):
                post_mean = tf.Variable(tf.zeros([d_in, d_out]), name="q_W")
                post_log_var = tf.Variable(tf.zeros([d_in, d_out]), name="q_W")
                tf.summary.histogram('posterior_mean', tf.reshape(post_mean, [-1]))
                tf.summary.histogram('posterior_logvar', tf.reshape(post_log_var, [-1]))
            
            mean_W.append(post_mean)
            log_var_W.append(post_log_var)
            
        return mean_W, log_var_W
    
    def get_std_norm_samples(self, d_in, d_out):
        """
        Draws N(0,1) samples of dimension [d_in, d_out].
        """
        return tf.random_normal(shape=[d_in, d_out])

    def sample_from_W(self):
        """
        Samples from the variational posterior approximation.
        We draw W-samples for each layer using the reparameterization trick.
        """

        for i in range(self.layers - 1):
            d_in = self.neurons_per_layer[i] + 1 # + 1 because of bias weight
            d_out = self.neurons_per_layer[i+1]
            z = self.get_std_norm_samples(d_in, d_out)
            ## division by 2 to obtain pure standard deviation
            w_from_q = tf.add(tf.multiply(z, tf.exp(self.log_var_W[i] / 2)), self.mean_W[i])
        
            yield w_from_q
    
    def feedforward(self, intermediate=0):
        """
        Feedforward pass excluding last layer's transfer function.
        intermediate : index of intermediate layer for output generation
        """
        
        # We will generate L output samples
        for i in range(self.L):
            
            outputs = self.X
            
            # Go through each layer (one weight matrix at a time)
            # and compute the (intermediate) output
            j = 0
            for weight_matrix in self.sample_from_W():
                outputs = tf.matmul(outputs, weight_matrix[1:,:]) + weight_matrix[0,:]
                tf.summary.histogram('activations', outputs)

                # if last layer is reached, do not use transfer function (softmax later on)
                if j == (self.layers - 2):
                    outputs = tf.sigmoid(outputs)
                else:
                    outputs = tf.nn.tanh(outputs)

                #outputs = tf.sigmoid(activations)
                tf.summary.histogram('outputs', outputs)

                #inputs = outputs
                j += 1
                
                if j == intermediate:
                    break
                
            # use generator to save memory space
            yield outputs
    
    def predict(self, intermediate=0):
        """
        Predict using monte carlo sampling.
        """
        
        expected_output = 0
        
        for output in self.feedforward(intermediate):
            expected_output += output
            
        return expected_output / self.L
    
    def get_ell(self):
        """
        Returns the expected log-likelihood of the lower bound.
        For this we draw L samples from W, compute the log-likelihood for each
        and average the log-likelihoods in the end (expectation approximation).
        """
        
        log_p = 0
        
        for output in self.feedforward():
            # y = tf.nn.softmax(tf.matmul(self.X, W_sample[i]) + b)
            # log_p_per_sample = tf.reduce_mean(tf.reduce_sum(self.Y * tf.log(y), reduction_indices=[1]))
            # soft_max_cross_entropy_with_logits is a numerically stable version of cross entropy
            # log_p_per_sample = tf.reduce_mean(-tf.nn.softmax_cross_entropy_with_logits(logits=output, labels=self.Y))
            
            log_p_per_sample = tf.reduce_mean(tf.reduce_sum(
                                    self.Y * tf.log(output + 1e-10) + (1 - self.Y) * tf.log(1 - output + 1e-10),
                                    reduction_indices=[1]))
            log_p += log_p_per_sample
        
        return log_p / self.L

    def get_kl(self, mean_W, log_var_W, prior_mean_W, log_prior_var_W):
        """
        KL[q || p] returns the KL-divergence between the prior p and the variational posterior q.
        :param mq: vector of means for q
        :param log_vq: vector of log-variances for q
        :param mp: vector of means for p
        :param log_vp: vector of log-variances for p
        :return: KL divergence between q and p
        """
        mq = mean_W
        log_vq = log_var_W
        mp = prior_mean_W
        log_vp = log_prior_var_W
        
        #log_vp = tf.reshape(log_vp, (-1, 1))
        return 0.5 * tf.reduce_sum(log_vp - log_vq + (tf.pow(mq - mp, 2) / tf.exp(log_vp)) + tf.exp(log_vq - log_vp) - 1)

    def get_kl_multi(self):
        """
        Compute KL divergence between variational and prior using a multi-layer-network
        """
        kl = 0
        
        for i in range(self.layers - 1):
            kl = kl + self.get_kl(
                        self.mean_W[i],
                        self.log_var_W[i],
                        self.prior_mean_W[i],
                        self.log_prior_var_W[i]
            )
        
        return kl
    
    def get_nelbo(self):
        """ Returns the negative ELBOW, which allows us to minimize instead of maximize. """
        kl = self.get_kl_multi()
        # ell, layer_out = self.get_ell()
        ell = self.get_ell()
        # DKL_gaussian - tf.mean([log_likelihood(w) for w in w_from_q])
        nelbo = kl - self.N/tf.cast(self.M, "float32") * ell
        # return nelbo, kl, ell, layer_out
        return nelbo, kl, ell
    
    def learn(self, learning_rate=0.01, epochs=50):
        """ Our learning procedure """
        optimizer = tf.train.AdamOptimizer(learning_rate)

        ## Set all_variables to contain the complete set of TF variables to optimize
        all_variables = tf.trainable_variables()

        ## Define the optimizer
        train_step = optimizer.minimize(self.loss, var_list=all_variables)

        tf.summary.scalar('negative_elbo', self.loss)
        tf.summary.scalar('kl_div', self.kl)
        tf.summary.scalar('ell', self.ell)
        
        merged = tf.summary.merge_all()
        
        train_writer = tf.summary.FileWriter('logs/train', self.session.graph)
        test_writer = tf.summary.FileWriter('logs/test')        
        
        ## Initialize all variables
        init = tf.global_variables_initializer()

        ## Initialize TF session
        self.session.run(init)
        

        for i in range(epochs):
            start_time = time.time()
            print("Epoch: ", i)
            train_cost = 0
            
            old_progress = 0
            for batch_i in range(mnist.train.num_examples // self.M):
                progress = round(float(batch_i) / (mnist.train.num_examples // self.M) * 100)
                if progress % 10 == 0 and progress != old_progress:
                    print('Progress: ', str(progress) + '%')
                    old_progress = progress
                batch_xs, _ = mnist.train.next_batch(self.M)

                _, loss, summary = self.session.run([train_step, self.loss, merged], feed_dict={self.X: batch_xs, self.Y: batch_xs})
                train_writer.add_summary(summary, i)
                train_cost += loss
            
            #summary, nelbo = self.session.run([merged, self.get_nelbo()],
            #                                  feed_dict={self.X: mnist.test.images, self.Y: mnist.test.images})
            #print("i=" + repr(i)  + "  kl=" + repr(nelbo[1]) + "  nell=" + repr(-nelbo[2])  + "  nelbo=" + repr(nelbo[0]), end="\n")
            print("NELBO: ", train_cost / (mnist.train.num_examples // batch_size))
            #test_writer.add_summary(summary, i)
            print('Epoch training time: ', time.time() - start_time)
        
        
        train_writer.close()
        test_writer.close()
        
    def benchmark(self, validation=False):
        if validation:
            benchmark_data = mnist.validation
            label = 'Validation loss:'
        else:
            benchmark_data = mnist.test
            label = 'Test loss:'
        
        cost = 0
        for batch_i in range(benchmark_data.num_examples // self.M):
            batch_xs, _ = benchmark_data.next_batch(batch_size)
            cost += self.session.run(self.loss,
                                   feed_dict={self.X: batch_xs, self.Y: batch_xs})
        print(label, cost /
              (benchmark_data.num_examples // self.M))
        
    def serialize(self, path):
        saver = tf.train.Saver()
        save_path = saver.save(self.session, path)
        print("Model saved in file: %s" % save_path)
        
    def restore(self, path):
        saver = tf.train.Saver()   
        sess = tf.Session()
        saver.restore(sess, save_path=path)
        self.session = sess
    
    def encode(self, input_vector, intermediate=0):
        input_vector = np.reshape(input_vector, [1, -1])
        output = self.predict(intermediate)
        return self.session.run(output, feed_dict={self.X: input_vector})

# %%
n_datapoints = mnist.train.num_examples
# including input neurons
mc_samples = 10
batch_size = 128
epochs = 100

# %%
# n_datapoints, n_layers, neurons_per_layer, mc_samples, batch_size
neurons_per_layer = [784, 32, 784]
vi = VariationalInference(n_datapoints, neurons_per_layer, mc_samples, batch_size, constant_prior=False)
vi.learn(learning_rate=0.01, epochs=epochs)
vi.benchmark()
# Out:
# Epoch:  0
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  216746.628988
# Epoch training time:  30.10268259048462
# Epoch:  1
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  104678.612835
# Epoch training time:  31.817543745040894
# Epoch:  2
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  81350.442417
# Epoch training time:  31.774864673614502
# Epoch:  3
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  72663.446132
# Epoch training time:  32.54040861129761
# Epoch:  4
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  68228.5825047
# Epoch training time:  33.673267126083374
# Epoch:  5
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  65630.8950503
# Epoch training time:  32.27040362358093
# Epoch:  6
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  63984.0749381
# Epoch training time:  32.40338182449341
# Epoch:  7
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  62840.2816233
# Epoch training time:  34.58031892776489
# Epoch:  8
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  62013.3613418
# Epoch training time:  31.715338945388794
# Epoch:  9
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  61034.8040683
# Epoch training time:  31.113856077194214
# Epoch:  10
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  60061.0735449
# Epoch training time:  32.29480791091919
# Epoch:  11
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  59584.4791667
# Epoch training time:  32.026686668395996
# Epoch:  12
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  59222.2031432
# Epoch training time:  32.108577489852905
# Epoch:  13
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  58915.2880518
# Epoch training time:  31.67468762397766
# Epoch:  14
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  58623.0539864
# Epoch training time:  34.275797605514526
# Epoch:  15
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  58238.6523802
# Epoch training time:  30.11043381690979
# Epoch:  16
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  57837.4421347
# Epoch training time:  32.00764203071594
# Epoch:  17
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  57569.3631356
# Epoch training time:  30.25200080871582
# Epoch:  18
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  56728.1655558
# Epoch training time:  31.175068140029907
# Epoch:  19
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  56386.461065
# Epoch training time:  32.75184416770935
# Epoch:  20
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  56207.5061189
# Epoch training time:  31.833305597305298
# Epoch:  21
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  56105.9321642
# Epoch training time:  30.277186155319214
# Epoch:  22
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  55923.5595954
# Epoch training time:  31.433033227920532
# Epoch:  23
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  55292.7430161
# Epoch training time:  30.943415880203247
# Epoch:  24
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  54523.1514332
# Epoch training time:  30.749056577682495
# Epoch:  25
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  54145.4152735
# Epoch training time:  31.75580072402954
# Epoch:  26
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  53596.2684841
# Epoch training time:  32.21034049987793
# Epoch:  27
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  52649.0754207
# Epoch training time:  30.891756296157837
# Epoch:  28
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  51429.6411258
# Epoch training time:  31.868598222732544
# Epoch:  29
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  50317.3820112
# Epoch training time:  34.11906337738037
# Epoch:  30
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  49127.2895906
# Epoch training time:  33.2940239906311
# Epoch:  31
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  40225.7481152
# Epoch training time:  29.815279960632324
# Epoch:  75
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  40156.9023529
# Epoch training time:  29.605074882507324
# Epoch:  76
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  40112.9665829
# Epoch training time:  29.53693127632141
# Epoch:  77
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  40100.2995975
# Epoch training time:  29.613672256469727
# Epoch:  78
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  39973.3604586
# Epoch training time:  29.712193250656128
# Epoch:  79
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  40023.0486324
# Epoch training time:  29.625532627105713
# Epoch:  80
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  39913.35057
# Epoch training time:  29.68052339553833
# Epoch:  81
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  39808.2555361
# Epoch training time:  29.59579873085022
# Epoch:  82
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  39765.4378733
# Epoch training time:  29.738529682159424
# Epoch:  83
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  39712.780212
# Epoch training time:  29.604408025741577
# Epoch:  84
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  39721.8200302
# Epoch training time:  29.753310680389404
# Epoch:  85
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  39633.5197407
# Epoch training time:  29.655110836029053
# Epoch:  86
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  39680.558011
# Epoch training time:  29.776002883911133
# Epoch:  87
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  39622.7071132
# Epoch training time:  30.578564167022705
# Epoch:  88
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  39637.6151479
# Epoch training time:  30.38443613052368
# Epoch:  89
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  39604.9683038
# Epoch training time:  29.648754835128784
# Epoch:  90
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  39573.695877
# Epoch training time:  29.78189706802368
# Epoch:  91
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  39590.2408672
# Epoch training time:  29.587641716003418
# Epoch:  92
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  39458.9162296
# Epoch training time:  29.635704278945923
# Epoch:  93
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  39530.8857809
# Epoch training time:  29.668548107147217
# Epoch:  94
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  39459.6268666
# Epoch training time:  29.955549478530884
# Epoch:  95
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  39319.9413061
# Epoch training time:  29.74757170677185
# Epoch:  96
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  39437.4461502
# Epoch training time:  29.629152059555054
# Epoch:  97
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  39309.1860704
# Epoch training time:  29.71957540512085
# Epoch:  98
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  39243.6539463
# Epoch training time:  29.78562068939209
# Epoch:  99
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  39213.3505973
# Epoch training time:  29.619648218154907
# Test loss: 38842.7887119

# %%
# n_datapoints, n_layers, neurons_per_layer, mc_samples, batch_size
neurons_per_layer = [784, 128, 64, 2, 64, 128, 784]
vi = VariationalInference(n_datapoints, neurons_per_layer, mc_samples, batch_size, constant_prior=False)
vi.learn(learning_rate=0.01, epochs=epochs)
vi.benchmark()
# Out:
# Epoch:  0
# Progress:  10
# Progress:  20
# Progress:  30
# Progress:  40
# Progress:  50
# Progress:  60
# Progress:  70
# Progress:  80
# Progress:  90
# Progress:  100
# NELBO:  608710.294216
# Epoch training time:  58.778414726257324
# Epoch:  1
# Progress:  10
# Progress:  20
# Progress:  30
# Progress:  40
# Progress:  50
# Progress:  60
# Progress:  70
# Progress:  80
# Progress:  90
# Progress:  100
# NELBO:  284779.657925
# Epoch training time:  58.72993087768555
# Epoch:  2
# Progress:  10
# Progress:  20
# Progress:  30
# Progress:  40
# Progress:  50
# Progress:  60
# Progress:  70
# Progress:  80
# Progress:  90
# Progress:  100
# NELBO:  211011.16368
# Epoch training time:  59.77456974983215
# Epoch:  3
# Progress:  10
# Progress:  20
# Progress:  30
# Progress:  40
# Progress:  50
# Progress:  60
# Progress:  70
# Progress:  80
# Progress:  90
# Progress:  100
# NELBO:  169700.964307
# Epoch training time:  59.38583278656006
# Epoch:  4
# Progress:  10
# Progress:  20
# Progress:  30
# Progress:  40
# Progress:  50
# Progress:  60
# Progress:  70
# Progress:  80
# Progress:  90
# Progress:  100
# NELBO:  144677.598904
# Epoch training time:  60.14256954193115
# Epoch:  5
# Progress:  10
# Progress:  20
# Progress:  30
# Progress:  40
# Progress:  50
# Progress:  60
# Progress:  70
# Progress:  80
# Progress:  90
# Progress:  100
# NELBO:  128670.971263
# Epoch training time:  60.33465528488159
# Epoch:  6
# Progress:  10
# Progress:  20
# Progress:  30
# Progress:  40
# Progress:  50
# Progress:  60
# Progress:  70
# Progress:  80
# Progress:  90
# Progress:  100
# NELBO:  118144.654265
# Epoch training time:  59.3399863243103
# Epoch:  7
# Progress:  10
# Progress:  20
# Progress:  30
# Progress:  40
# Progress:  50
# Progress:  60
# Progress:  70
# Progress:  80
# Progress:  90
# Progress:  100
# NELBO:  110836.693382
# Epoch training time:  61.95111083984375
# Epoch:  8
# Progress:  10
# Progress:  20
# Progress:  30
# Progress:  40
# Progress:  50
# Progress:  60
# Progress:  70
# Progress:  80
# Progress:  90
# Progress:  100
# NELBO:  105782.157288
# Epoch training time:  65.37501096725464
# Epoch:  9
# Progress:  10
# Progress:  20
# Progress:  30
# Progress:  40
# Progress:  50
# Progress:  60
# Progress:  70
# Progress:  80
# Progress:  90
# Progress:  100
# NELBO:  102084.528646
# Epoch training time:  65.08343553543091
# Epoch:  10
# Progress:  10
# Progress:  20
# Progress:  30
# Progress:  40
# Progress:  50
# Progress:  60
# Progress:  70
# Progress:  80
# Progress:  90
# Progress:  100
# NELBO:  99351.5425226
# Epoch training time:  65.08508563041687
# Epoch:  11
# Progress:  10
# Progress:  20
# Progress:  30
# Progress:  40
# Progress:  50
# Progress:  60
# Progress:  70
# Progress:  80
# Progress:  90
# Progress:  100
# NELBO:  97304.7950357
# Epoch training time:  65.07253527641296
# Epoch:  12
# Progress:  10
# Progress:  20
# Progress:  30
# Progress:  40
# Progress:  50
# Progress:  60
# Progress:  70
# Progress:  80
# Progress:  90
# Progress:  100
# NELBO:  95732.9868335
# Epoch training time:  64.5537497997284
# Epoch:  13
# Progress:  10
# Progress:  20
# Progress:  30
# Progress:  40
# Progress:  50
# Progress:  60
# Progress:  70
# Progress:  80
# Progress:  90
# Progress:  100
# NELBO:  94668.0786167
# Epoch training time:  64.2313244342804
# Epoch:  14
# Progress:  10
# Progress:  20
# Progress:  30
# Progress:  40
# Progress:  50
# Progress:  60
# Progress:  70
# Progress:  80
# Progress:  90
# Progress:  100
# NELBO:  93644.1753351
# Epoch training time:  65.8041250705719
# Epoch:  15
# Progress:  10
# Progress:  20
# Progress:  30
# Progress:  40
# Progress:  50
# Progress:  60
# Progress:  70
# Progress:  80
# Progress:  90
# Progress:  100
# NELBO:  92923.6442854
# Epoch training time:  65.1499285697937
# Epoch:  16
# Progress:  10
# Progress:  20
# Progress:  30
# Progress:  40
# Progress:  50
# Progress:  60
# Progress:  70
# Progress:  80
# Progress:  90
# Progress:  100
# NELBO:
# %%
# n_datapoints, n_layers, neurons_per_layer, mc_samples, batch_size
neurons_per_layer = [784, 128, 64, 32, 64, 128, 784]
vi = VariationalInference(n_datapoints, neurons_per_layer, mc_samples, batch_size, constant_prior=False)
vi.learn(learning_rate=0.01, epochs=epochs)
vi.benchmark()
# Out:
# Epoch:  0
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  517935.414736
# Epoch training time:  56.420615434646606
# Epoch:  1
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  197641.897327
# Epoch training time:  67.83362650871277
# Epoch:  2
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  147366.352947
# Epoch training time:  66.61535954475403
# Epoch:  3
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  124362.107026
# Epoch training time:  58.995502948760986
# Epoch:  4
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  112274.711174
# Epoch training time:  58.17321729660034
# Epoch:  5
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  105117.214361
# Epoch training time:  58.52111530303955
# Epoch:  6
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  100688.31128
# Epoch training time:  57.575655937194824
# Epoch:  7
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  97749.7955456
# Epoch training time:  58.14444088935852
# Epoch:  8
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  95703.3032306
# Epoch training time:  59.96929883956909
# Epoch:  9
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  94200.3658035
# Epoch training time:  58.387911558151245
# Epoch:  10
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  93130.7533872
# Epoch training time:  57.40381073951721
# Epoch:  11
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  92295.6635344
# Epoch training time:  60.97298622131348
# Epoch:  12
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  88357.4425991
# Epoch training time:  58.17443561553955
# Epoch:  13
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  84853.2138513
# Epoch training time:  57.578702211380005
# Epoch:  14
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  82627.1005245
# Epoch training time:  57.50679540634155
# Epoch:  15
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  81138.3295637
# Epoch training time:  57.131200075149536
# Epoch:  16
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  79601.2729276
# Epoch training time:  57.2821102142334
# Epoch:  17
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  77667.0612799
# Epoch training time:  57.26894450187683
# Epoch:  18
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  74801.1195003
# Epoch training time:  57.545963764190674
# Epoch:  19
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  72238.5260963
# Epoch training time:  57.622138261795044
# Epoch:  20
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  69926.0285548
# Epoch training time:  57.476438760757446
# Epoch:  21
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  68101.5155339
# Epoch training time:  57.315369606018066
# Epoch:  22
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  66822.2421875
# Epoch training time:  57.712321758270264
# Epoch:  23
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  65761.3924916
# Epoch training time:  59.7343385219574
# Epoch:  24
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  65314.051619
# Epoch training time:  57.64197826385498
# Epoch:  25
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  64753.9234047
# Epoch training time:  58.26808428764343
# Epoch:  26
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  64186.9321005
# Epoch training time:  58.32547664642334
# Epoch:  27
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  63799.612917
# Epoch training time:  57.44284176826477
# Epoch:  28
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  63417.3897418
# Epoch training time:  57.96532082557678
# Epoch:  29
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  63204.9512402
# Epoch training time:  58.10050582885742
# Epoch:  30
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  62813.0600324
# Epoch training time:  57.714855909347534
# Epoch:  31
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  62452.3913079
# Epoch training time:  59.48625707626343
# Epoch:  32
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  62224.7856935
# Epoch training time:  57.83803749084473
# Epoch:  33
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  61933.5258596
# Epoch training time:  59.12398052215576
# Epoch:  34
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  61660.7215545
# Epoch training time:  58.010035037994385
# Epoch:  35
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  61612.5197043
# Epoch training time:  61.21213960647583
# Epoch:  36
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  61268.5227546
# Epoch training time:  58.376442432403564
# Epoch:  37
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  61272.0980205
# Epoch training time:  57.2333927154541
# Epoch:  38
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  60920.6688429
# Epoch training time:  57.96676254272461
# Epoch:  39
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  60816.5632831
# Epoch training time:  57.587841749191284
# Epoch:  40
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  60494.9022891
# Epoch training time:  57.36950898170471
# Epoch:  41
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  56940.4799315
# Epoch training time:  57.627142906188965
# Epoch:  85
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  56884.7645414
# Epoch training time:  57.999181270599365
# Epoch:  86
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  56885.9969315
# Epoch training time:  57.420573711395264
# Epoch:  87
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  56860.6366004
# Epoch training time:  57.591087341308594
# Epoch:  88
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  56654.2982499
# Epoch training time:  57.53889536857605
# Epoch:  89
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  56883.6179979
# Epoch training time:  57.82588863372803
# Epoch:  90
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  56901.586329
# Epoch training time:  58.24905323982239
# Epoch:  91
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  56753.9718185
# Epoch training time:  57.613731384277344
# Epoch:  92
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  56839.710118
# Epoch training time:  57.62039256095886
# Epoch:  93
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  56782.32044
# Epoch training time:  57.72238516807556
# Epoch:  94
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  56698.7139241
# Epoch training time:  57.560532569885254
# Epoch:  95
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  56651.7754589
# Epoch training time:  57.848907232284546
# Epoch:  96
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  56631.4684222
# Epoch training time:  61.02261400222778
# Epoch:  97
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  56613.6387766
# Epoch training time:  59.16604924201965
# Epoch:  98
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  56716.0986123
# Epoch training time:  58.27946162223816
# Epoch:  99
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  56466.521325
# Epoch training time:  58.64428973197937
# Test loss: 56275.0827324

# %%
# n_datapoints, n_layers, neurons_per_layer, mc_samples, batch_size
neurons_per_layer = [784, 2048, 2048, 2, 2048, 2048, 784]
vi = VariationalInference(n_datapoints, neurons_per_layer, mc_samples, batch_size, constant_prior=False)
vi.learn(learning_rate=0.01, epochs=epochs)
vi.benchmark()
# Out:
# Epoch:  0
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  1671818.09703
# Epoch training time:  1753.3526215553284
# Epoch:  1
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  990396.455565
# Epoch training time:  1692.6844832897186
# Epoch:  2
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  997214.737325
# Epoch training time:  1675.9248542785645
# Epoch:  3
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  1001964.49971
# Epoch training time:  1664.5607013702393
# Epoch:  4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-76775fc559b3> in <module>()
#       2 neurons_per_layer = [784, 2048, 2048, 2, 2048, 2048, 784]
#       3 vi = VariationalInference(n_datapoints, neurons_per_layer, mc_samples, batch_size, constant_prior=False)
# ----> 4 vi.learn(learning_rate=0.01, epochs=epochs)
#       5 vi.benchmark()
#
# <ipython-input-4-11edbbbcaa2c> in learn(self, learning_rate, epochs)
#     269                 batch_xs, _ = mnist.train.next_batch(self.M)
#     270
# --> 271                 _, loss, summary = self.session.run([train_step, self.loss, merged], feed_dict={self.X: batch_xs, self.Y: batch_xs})
#     272                 train_writer.add_summary(summary, i)
#     273                 train_cost += loss
#
# ~/python-projects/environments/tf-simd/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/python-projects/environments/tf-simd/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# ~/python-projects/environments/tf-simd/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/python-projects/environments/tf-simd/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# ~/python-projects/environments/tf-simd/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# 2_hidden: [784, 128, 64, 2, 64, 128, 784]
# vi.serialize('tmp/model_2_hidden.ckpt')
vi.serialize('tmp/model_shallow.ckpt')
# Out:
# Model saved in file: tmp/model_shallow.ckpt

# %%
tf.reset_default_graph()     
neurons_per_layer = [784, 512, 32, 512, 784]
vi = VariationalInference(n_datapoints, neurons_per_layer, mc_samples, batch_size, constant_prior=False)
vi.restore('tmp/model.ckpt')
# Out:
# INFO:tensorflow:Restoring parameters from ./tmp/model.ckpt

# %%
def plot_enc_dec():
    n = 10  # how many digits we will display
    plt.figure(figsize=(20, 4))
    for i in range(n):
        # display original
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(mnist.test.images[i].reshape(28, 28))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # display reconstruction
        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(vi.encode(mnist.test.images[i]).reshape(28, 28))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# %% [markdown]
# ### Results with [784, 128, 64, 2, 64, 128, 784] architecture and 100 epochs (converged)

# %%
plot_enc_dec()

# %% [markdown]
# ### Results with [784, 128, 64, 32, 64, 128, 784] architecture and 100 epochs (converged)

# %%
plot_enc_dec()

# %%
plot_enc_dec()
