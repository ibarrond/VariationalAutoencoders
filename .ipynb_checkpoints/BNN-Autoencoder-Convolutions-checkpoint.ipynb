# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import gc
import math

# %%
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
sess = tf.Session()
sess.run(tf.sigmoid(tf.ones([2,3,2]))[:,1:,:])
# Out:
# array([[[ 0.7310586,  0.7310586],
#         [ 0.7310586,  0.7310586]],
#
#        [[ 0.7310586,  0.7310586],
#         [ 0.7310586,  0.7310586]]], dtype=float32)

# %%
tf.sigmoid(tf.ones([5,3,2]))
# Out:
# <tf.Tensor 'Sigmoid_1:0' shape=(5, 3, 2) dtype=float32>

# %%
mc = 5
batch_size = 3
Din = 2

X = tf.random_normal([batch_size, Din])
tens = tf.multiply(tf.ones([mc, batch_size, Din]), X)

tens = tf.matmul(tens, tf.random_normal([mc, Din, 2*Din]))


sess = tf.Session()
sess.run(tens)
# Out:
# array([[[-0.11135516,  0.2765055 , -0.58164316, -0.16078733],
#         [ 0.18534203, -0.47609961,  1.00594819,  0.28827778],
#         [ 0.22544473, -0.42611352,  0.85889214,  0.15157071]],
#
#        [[ 0.16972613,  0.32254413, -0.56507647,  0.30458999],
#         [-0.28994685, -0.56199336,  0.98177004, -0.51654112],
#         [-0.28088492, -0.44130275,  0.79675972, -0.53604215]],
#
#        [[ 0.84895802,  0.62798584,  0.75696599, -0.67824537],
#         [-1.45672357, -1.0769875 , -1.30377126,  1.16388977],
#         [-1.35082698, -1.00403082, -1.16322553,  1.07842624]],
#
#        [[-0.85498685, -0.18053003,  0.61956024,  1.25952053],
#         [ 1.47990346,  0.31407833, -1.0545882 , -2.16401744],
#         [ 1.25234985,  0.25098255, -1.05749238, -1.98042524]],
#
#        [[-1.42528391,  0.09106559, -0.36136189,  1.30444837],
#         [ 2.43501163, -0.16072711,  0.62178731, -2.23906898],
#         [ 2.35733008, -0.10727955,  0.56043494, -2.06908727]]], dtype=float32)

# %%
def lrelu(x, leak=0.2, name="lrelu"):
    """Leaky rectifier.
    Parameters
    ----------
    x : Tensor
        The tensor to apply the nonlinearity to.
    leak : float, optional
        Leakage parameter.
    name : str, optional
        Variable scope to use.
    Returns
    -------
    x : Tensor
        Output of the nonlinearity.
    """
    with tf.variable_scope(name):
        f1 = 0.5 * (1 + leak)
        f2 = 0.5 * (1 - leak)
        return f1 * x + f2 * abs(x)

# %%
class VariationalInference(object):
    def __init__(self, num_examples, mc_samples, batch_size, constant_prior=False):
        tf.reset_default_graph()
        
        # SIZES
        self.N = num_examples
        self.M = batch_size
        ## Set the number of Monte Carlo samples as a placeholder so that it can be different for training and test
        self.L = mc_samples
        
        self.constant_prior = constant_prior
        
        ## Batch data placeholders
        with tf.name_scope('input'):
            self.X = tf.placeholder(tf.float32, shape=[None, 784], name='x-input')
            self.Y = tf.placeholder(tf.float32, shape=[None, 784], name='y-input')
            
        with tf.name_scope('input_reshape'):
            self.X_reshaped = tf.reshape(self.X, [-1, 28, 28, 1])
            tf.summary.image('input', self.X_reshaped, 10)
            
        self.phase = tf.placeholder(tf.bool, name='phase')

        self.weights = {}
        
        self.initialize_model_weights()
        
        ## Initialize the session
        self.session = tf.Session()
        
        ## Builds whole computational graph with relevant quantities as part of the class
        self.loss, self.kl, self.ell, self.layer_out = self.get_nelbo()
        
    def add_weights(self, shape, bias_shape, name):
        
        with tf.name_scope(name + "_weights"):
            self.weights[name] = {}
            
            # PRIORS
            if self.constant_prior:
                self.weights[name]['prior_mean'] = tf.constant(0.0, shape=shape, name="prior_mean")
                self.weights[name]['prior_mean_bias'] = tf.constant(0.0, shape=bias_shape, name="prior_mean_bias")
                self.weights[name]['prior_log_var'] = tf.constant(0.0, shape=shape, name="prior_log_var")
                self.weights[name]['prior_log_var_bias'] = tf.constant(0.0, shape=bias_shape, name="prior_log_var_bias")
            else:
                self.weights[name]['prior_mean'] = tf.Variable(tf.zeros(shape), name="prior_mean")
                self.weights[name]['prior_mean_bias'] = tf.Variable(tf.zeros(bias_shape), name="prior_mean_bias")
                self.weights[name]['prior_log_var'] = tf.Variable(tf.zeros(shape), name="prior_log_var")
                self.weights[name]['prior_log_var_bias'] = tf.Variable(tf.zeros(bias_shape), name="prior_log_var_bias")


            #tf.summary.histogram('prior_mean', self.weights[name]['prior_mean'])
            #tf.summary.histogram('prior_logvar', self.weights[name]['prior_log_var'])
        
            # POSTERIORS
            self.weights[name]['post_mean'] = tf.Variable(tf.zeros(shape), name="post_mean")
            self.weights[name]['post_mean_bias'] = tf.Variable(tf.zeros(bias_shape), name="post_mean_bias")
            self.weights[name]['post_log_var'] = tf.Variable(tf.zeros(shape), name="post_log_var")
            self.weights[name]['post_log_var_bias'] = tf.Variable(tf.zeros(bias_shape), name="post_log_var_bias")
            
            #tf.summary.histogram('posterior_mean', self.weights[name]['post_mean'])
            #tf.summary.histogram('posterior_logvar', self.weights[name]['post_log_var'])
            
    def initialize_model_weights(self):        
        # convolution
        self.add_weights([3, 3, 1, 10], [10], 'W_conv1')
        self.add_weights([3, 3, 10, 10], [10], 'W_conv2')
        self.add_weights([3, 3, 10, 10], [10], 'W_conv3')
        
        # "deconvolution"
        self.add_weights([3, 3, 10, 10], [10], 'W_conv4')
        self.add_weights([3, 3, 10, 10], [10], 'W_conv5')
        self.add_weights([3, 3, 1, 10], [1], 'W_conv6')
        
        # increase feature maps while decreasing size
    
    def get_std_norm_samples(self, shape):
        """
        Draws N(0,1) samples of dimension shape.
        """
        return tf.random_normal(shape=shape)

    def sample_from_W(self, layer_name, bias=False):
        """
        Samples from the variational posterior approximation.
        We draw W-samples using the reparameterization trick.
        """
        if bias:
            mean_W = self.weights[layer_name]['post_mean_bias']
            log_var_W = self.weights[layer_name]['post_log_var_bias']
        else:
            mean_W = self.weights[layer_name]['post_mean']
            log_var_W = self.weights[layer_name]['post_log_var']
        
        shape = mean_W.shape
        
        z = self.get_std_norm_samples(shape)
        ## division by 2 to obtain pure standard deviation
        w_from_q = tf.add(tf.multiply(z, tf.exp(log_var_W / 2)), mean_W)
        
        return w_from_q
    
    def feedforward(self):
        """
        Feedforward pass excluding last layer's transfer function.
        intermediate : index of intermediate layer for output generation
        """
        
        # We will generate L output samples
        for i in range(self.L):
            
            # ENCODING
            
            outputs = self.X_reshaped
            
            W = self.sample_from_W('W_conv1')
            W_bias = self.sample_from_W('W_conv1', bias=True)
            
            outputs = tf.add(tf.nn.conv2d(
                outputs, W, strides=[1, 2, 2, 1], padding='SAME'), W_bias)
            
            # tf.summary.histogram('layer_one_activations', outputs)
            # outputs = tf.layers.batch_normalization(outputs, training=self.phase)
            outputs = lrelu(outputs)
            
            W = self.sample_from_W('W_conv2')
            W_bias = self.sample_from_W('W_conv2', bias=True)
            
            outputs = tf.add(tf.nn.conv2d(
                outputs, W, strides=[1, 2, 2, 1], padding='SAME'), W_bias)
            #tf.summary.histogram('layer_two_activations', outputs)
            #outputs = tf.layers.batch_normalization(outputs, training=self.phase)
            outputs = lrelu(outputs)
            
            W = self.sample_from_W('W_conv3')
            W_bias = self.sample_from_W('W_conv3', bias=True)
            
            outputs = tf.add(tf.nn.conv2d(
                outputs, W, strides=[1, 2, 2, 1], padding='SAME'), W_bias)
            #tf.summary.histogram('layer_three_activations', outputs)
            #outputs = tf.layers.batch_normalization(outputs, training=self.phase)
            outputs = lrelu(outputs)
            
            # Latent representation
            z = outputs
            
            # DECODING
            W = self.sample_from_W('W_conv4')
            W_bias = self.sample_from_W('W_conv4', bias=True)
            
            outputs = tf.add(
                tf.nn.conv2d_transpose(
                    outputs, W,
                    tf.stack([tf.shape(self.X_reshaped)[0], 7, 7, 10]),
                    strides=[1, 2, 2, 1], padding='SAME'), W_bias)
            #tf.summary.histogram('layer_four_activations', outputs)
            #outputs = tf.layers.batch_normalization(outputs, training=self.phase)
            outputs = lrelu(outputs)
            
            W = self.sample_from_W('W_conv5')
            W_bias = self.sample_from_W('W_conv5', bias=True)
            
            outputs = tf.add(
                tf.nn.conv2d_transpose(
                    outputs, W,
                    tf.stack([tf.shape(self.X_reshaped)[0], 14, 14, 10]),
                    strides=[1, 2, 2, 1], padding='SAME'), W_bias)
            # tf.summary.histogram('layer_five_activations', outputs)
            #outputs = tf.layers.batch_normalization(outputs, training=self.phase)
            outputs = lrelu(outputs)
            
            W = self.sample_from_W('W_conv6')
            W_bias = self.sample_from_W('W_conv6', bias=True)
            
            outputs = tf.add(
                tf.nn.conv2d_transpose(
                    outputs, W,
                    tf.stack([tf.shape(self.X_reshaped)[0], 28, 28, 1]),
                    strides=[1, 2, 2, 1], padding='SAME'), W_bias)
            #tf.summary.histogram('layer_six_activations', outputs)
            #outputs = tf.layers.batch_normalization(outputs, training=self.phase)
            # outputs = tf.sigmoid(outputs)
            outputs = lrelu(outputs)

            yield tf.contrib.layers.flatten(outputs)

    """
    # Bernoulli Likelihood
    def get_ll(self, Y, output):
        return tf.reduce_sum(
            Y * tf.log(output + 1e-10) + \
            (1 - Y) * tf.log(1 - output + 1e-10),
            reduction_indices=[1]
        )
    """
    
    # Gaussian Likelihood with stddev=1
    def get_ll(self, Y, output):
        return tf.reduce_sum(-0.5 * tf.log(2*math.pi) - 0.5 * tf.square(output - Y), reduction_indices=[1])

    # def get_ll(self, Y, output):
    #     return tf.reduce_sum(tf.square(Y - output))
    
    # def get_ll(self, Y, output):
    #    return tf.nn.sigmoid_cross_entropy_with_logits(labels=Y, logits=output)


    
    def get_ell(self):
        """
        Returns the expected log-likelihood of the lower bound.
        For this we draw L samples from W, compute the log-likelihood for each
        and average the log-likelihoods in the end (expectation approximation).
        The log-likelihoods are returned for a batch of data.
        """
        
        batch_log_p = 0
        cum_output = 0
        inters = []
        
        for output in self.feedforward():
            # y = tf.nn.softmax(tf.matmul(self.X, W_sample[i]) + b)
            # log_p_per_sample = tf.reduce_mean(tf.reduce_sum(self.Y * tf.log(y), reduction_indices=[1]))
            # soft_max_cross_entropy_with_logits is a numerically stable version of cross entropy
            # log_p_per_sample = tf.reduce_mean(-tf.nn.softmax_cross_entropy_with_logits(logits=output, labels=self.Y))
            batch_log_p += self.get_ll(self.Y, output)
            cum_output += output
            
        
        ell = batch_log_p / self.L
        avg_output = cum_output / self.L
        
        return ell, avg_output

    def get_kl(self, layer_name):
        """
        KL[q || p] returns the KL-divergence between the prior p and the variational posterior q.
        :param mq: vector of means for q
        :param log_vq: vector of log-variances for q
        :param mp: vector of means for p
        :param log_vp: vector of log-variances for p
        :return: KL divergence between q and p
        """
        mq = self.weights[layer_name]['post_mean']
        mq_b = self.weights[layer_name]['post_mean_bias']
        log_vq = self.weights[layer_name]['post_log_var']
        log_vq_b = self.weights[layer_name]['post_log_var_bias']
        mp = self.weights[layer_name]['prior_mean']
        mp_b = self.weights[layer_name]['prior_mean_bias']
        log_vp = self.weights[layer_name]['prior_log_var']
        log_vp_b = self.weights[layer_name]['prior_log_var_bias']
        
        kl_normal = 0.5 * tf.reduce_sum(log_vp - log_vq + (tf.pow(mq - mp, 2) / tf.exp(log_vp)) \
                                   + tf.exp(log_vq - log_vp) - 1)
        
        kl_bias = 0.5 * tf.reduce_sum(log_vp_b - log_vq_b + (tf.pow(mq_b - mp_b, 2) / tf.exp(log_vp_b)) \
                                   + tf.exp(log_vq_b - log_vp_b) - 1)
        
        #log_vp = tf.reshape(log_vp, (-1, 1))
        return kl_normal + kl_bias

    def get_kl_multi(self):
        """
        Compute KL divergence between variational and prior using a multi-layer-network
        """
        kl = 0
        
        # instead of going through the layers, we have to go through the filters/weight matrices
        for key in self.weights.keys():
            kl = kl + self.get_kl(key)
        
        return kl
    
    def get_nelbo(self):
        """ Returns the negative ELBOW, which allows us to minimize instead of maximize. """
        # the kl does not change among samples
        kl = self.get_kl_multi()
        ell, layer_out = self.get_ell()
        # we take the mean instead of the sum to give it the same weight as for the KL-term
        batch_ell = tf.reduce_mean(ell)
        nelbo = kl - batch_ell # * self.N / float(self.M)
        return nelbo, kl, batch_ell, layer_out
    
    def learn(self, learning_rate=0.01, epochs=50, mc_samples=1):
        """ Our learning procedure """
        optimizer = tf.train.AdamOptimizer(learning_rate)

        ## Set all_variables to contain the complete set of TF variables to optimize
        all_variables = tf.trainable_variables()
        
        ## Define the optimizer
        train_step = optimizer.minimize(self.loss, var_list=all_variables)

        tf.summary.scalar('negative_elbo', self.loss)
        tf.summary.scalar('kl_div', self.kl)
        tf.summary.scalar('ell', self.ell)
        
        merged = tf.summary.merge_all()
        
        train_writer = tf.summary.FileWriter('logs/train', self.session.graph)
        test_writer = tf.summary.FileWriter('logs/test')        
        
        ## Initialize all variables
        init = tf.global_variables_initializer()
        #init_l = tf.local_variables_initializer()

        ## Initialize TF session
        self.session.run(init)
        #self.session.run(init_l)
        
        mean_img = np.mean(mnist.train.images, axis=0)

        for i in range(epochs):
            start_time = time.time()
            print("Epoch: ", i)
            train_cost = 0
            cum_ell = 0
            cum_kl = 0
            
            old_progress = 0
            for batch_i in range(mnist.train.num_examples // self.M):
                progress = round(float(batch_i) / (mnist.train.num_examples // self.M) * 100)
                if progress % 10 == 0 and progress != old_progress:
                    print('Progress: ', str(progress) + '%')
                    old_progress = progress

                batch_xs, _ = mnist.train.next_batch(self.M)
                train = np.array([img - mean_img for img in batch_xs])

                _, loss, ell, kl, summary = self.session.run(
                    [train_step, self.loss, self.ell, self.kl, merged],
                    feed_dict={self.X: train, self.Y: train, self.phase: True})
                train_writer.add_summary(summary, i)
                train_cost += loss
                cum_ell += ell
                cum_kl += kl
            

            print("NELBO: ", train_cost / (mnist.train.num_examples // self.M))
            print("ELL: ", -cum_ell / (mnist.train.num_examples // self.M))
            print("KL: ", cum_kl / (mnist.train.num_examples // self.M))
            print('Epoch training time: ', time.time() - start_time)
            
            val_cost = self.benchmark(validation=True)
            print('Validation cost: ', val_cost)
        
        
        train_writer.close()
        test_writer.close()
        
    def benchmark(self, validation=False):
        mean_img = np.mean(mnist.train.images, axis=0)
        
        if validation:
            benchmark_data = mnist.validation
            label = 'Validation loss:'
        else:
            benchmark_data = mnist.test
            label = 'Test loss:'
        
        cost = 0
        for batch_i in range(benchmark_data.num_examples // self.M):
            batch_xs, _ = benchmark_data.next_batch(batch_size)
            train = np.array([img - mean_img for img in batch_xs])
            cost += self.session.run(self.loss,
                                   feed_dict={self.X: train, self.Y: train, self.phase: False})
        return cost / (benchmark_data.num_examples // self.M)
        
    def serialize(self, path):
        saver = tf.train.Saver()
        save_path = saver.save(self.session, path)
        print("Model saved in file: %s" % save_path)
        
    def restore(self, path):
        saver = tf.train.Saver()   
        sess = tf.Session()
        saver.restore(sess, save_path=path)
        self.session = sess
    
    def predict(self, batch):
        outputs = self.layer_out
        return self.session.run(outputs, feed_dict={self.X: batch, self.Y: batch, self.phase: False})
    
    def get_weights(self, layer_name, weight_type):
        return self.session.run(self.weights[layer_name][weight_type])

# %%
n_datapoints = mnist.train.num_examples
# including input neurons
batch_size = 100
epochs = 100
mc_samples = 10

# %%
# n_datapoints, n_layers, neurons_per_layer, mc_samples, batch_size
vi = VariationalInference(n_datapoints, mc_samples, batch_size, constant_prior=False)
vi.learn(learning_rate=0.01, epochs=epochs)
vi.benchmark()
# Out:
# Epoch:  0
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  19626408.4173
# ELL:  19626408.4173
# KL:  0.00667363573204
# Epoch training time:  82.40653443336487
# Validation cost:  2992545.1975
# Epoch:  1
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  1883566.09625
# ELL:  1883566.09625
# KL:  7.6740600846e-05
# Epoch training time:  86.99463391304016
# Validation cost:  1126589.4875
# Epoch:  2
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  817838.466307
# ELL:  817838.466307
# KL:  8.63005898216e-05
# Epoch training time:  84.07944536209106
# Validation cost:  545689.865
# Epoch:  3
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  417298.67125
# ELL:  417298.67125
# KL:  0.000193134112792
# Epoch training time:  82.78539276123047
# Validation cost:  313366.187188
# Epoch:  4
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  244265.362514
# ELL:  244265.362514
# KL:  0.000289449745959
# Epoch training time:  82.52977657318115
# Validation cost:  186156.943438
# Epoch:  5
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  160211.602429
# ELL:  160211.602429
# KL:  0.000333869944919
# Epoch training time:  82.247642993927
# Validation cost:  120965.028281
# Epoch:  6
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  108270.017543
# ELL:  108270.017543
# KL:  0.000367864695462
# Epoch training time:  84.44797015190125
# Validation cost:  96415.0032031
# Epoch:  7
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  75397.1584446
# ELL:  75397.1584446
# KL:  0.000378670963374
# Epoch training time:  85.02284979820251
# Validation cost:  64430.9465625
# Epoch:  8
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  52713.8517791
# ELL:  52713.8517756
# KL:  0.000397271188823
# Epoch training time:  83.04153728485107
# Validation cost:  43361.9623437
# Epoch:  9
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  37589.3008114
# ELL:  37589.3008114
# KL:  0.000398706956343
# Epoch training time:  83.4949197769165
# Validation cost:  31737.4641797
# Epoch:  10
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  26747.3766246
# ELL:  26747.3766193
# KL:  0.00041190775958
# Epoch training time:  82.60881638526917
# Validation cost:  22291.2917578
# Epoch:  11
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  19545.0735147
# ELL:  19545.0734703
# KL:  0.000419311956926
# Epoch training time:  86.21370720863342
# Validation cost:  16293.5593359
# Epoch:  12
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  14029.0885227
# ELL:  14029.0884242
# KL:  0.000420573028651
# Epoch training time:  82.2829384803772
# Validation cost:  12740.8992773
# Epoch:  13
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  10423.3734686
# ELL:  10423.3732058
# KL:  0.000435188466852
# Epoch training time:  82.02994751930237
# Validation cost:  9270.8659375
# Epoch:  14
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  7765.88354093
# ELL:  7765.88315563
# KL:  0.000440583174879
# Epoch training time:  82.80392122268677
# Validation cost:  7132.2757666
# Epoch:  15
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  5921.83423162
# ELL:  5921.83376199
# KL:  0.000453214049339
# Epoch training time:  82.21619987487793
# Validation cost:  5440.24440918
# Epoch:  16
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  4812.47091087
# ELL:  4812.47043279
# KL:  0.000460657694123
# Epoch training time:  82.0441837310791
# Validation cost:  4052.63980957
# Epoch:  17
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  3887.85428533
# ELL:  3887.85377907
# KL:  0.000491040403193
# Epoch training time:  82.35187840461731
# Validation cost:  3427.93416016
# Epoch:  18
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  3194.36001665
# ELL:  3194.35950728
# KL:  0.000492905974388
# Epoch training time:  83.80730319023132
# Validation cost:  2959.53481934
# Epoch:  19
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  2680.43297696
# ELL:  2680.43243741
# KL:  0.000537860501896
# Epoch training time:  82.86083912849426
# Validation cost:  2285.75528809
# Epoch:  20
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  2240.40008345
# ELL:  2240.39957497
# KL:  0.000500028837811
# Epoch training time:  82.8836898803711
# Validation cost:  2123.60689941
# Epoch:  21
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  1975.62964156
# ELL:  1975.62903831
# KL:  0.000601808320392
# Epoch training time:  83.15506076812744
# Validation cost:  1758.37766357
# Epoch:  22
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  1708.05590776
# ELL:  1708.05529585
# KL:  0.000610947283832
# Epoch training time:  82.931560754776
# Validation cost:  1609.42141602
# Epoch:  23
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  1544.25300826
# ELL:  1544.25228715
# KL:  0.000721898024732
# Epoch training time:  82.64999270439148
# Validation cost:  1496.00389404
# Epoch:  24
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  1413.58288952
# ELL:  1413.58205167
# KL:  0.000840300321579
# Epoch training time:  82.986887216568
# Validation cost:  1313.71501953
# Epoch:  25
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  1289.9902599
# ELL:  1289.98930731
# KL:  0.000952152501453
# Epoch training time:  82.98428988456726
# Validation cost:  1241.12299561
# Epoch:  26
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  1198.96837469
# ELL:  1198.96714622
# KL:  0.00122580111027
# Epoch training time:  83.0048418045044
# Validation cost:  1176.03102539
# Epoch:  27
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  1119.03245594
# ELL:  1119.03095426
# KL:  0.00150279131803
# Epoch training time:  82.81801199913025
# Validation cost:  1112.14880615
# Epoch:  28
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  1054.62063055
# ELL:  1054.61848034
# KL:  0.00215152572502
# Epoch training time:  83.16974234580994
# Validation cost:  1005.50248657
# Epoch:  29
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  991.607473145
# ELL:  991.605073131
# KL:  0.00239983818748
# Epoch training time:  82.73943424224854
# Validation cost:  944.65862915
# Epoch:  30
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  940.311691007
# ELL:  940.308559459
# KL:  0.00313193472949
# Epoch training time:  82.53364109992981
# Validation cost:  924.968990479
# Epoch:  31
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  903.712042347
# ELL:  903.707306574
# KL:  0.00473585139621
# Epoch training time:  82.8597412109375
# Validation cost:  890.007827148
# Epoch:  32
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  866.205411821
# ELL:  866.201105957
# KL:  0.00430552796884
# Epoch training time:  83.86824369430542
# Validation cost:  858.555593262
# Epoch:  33
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  840.487575573
# ELL:  840.482559371
# KL:  0.00501671650193
# Epoch training time:  83.0178554058075
# Validation cost:  829.589884033
# Epoch:  34
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  819.044957497
# ELL:  819.038652011
# KL:  0.00630599617958
# Epoch training time:  82.69987773895264
# Validation cost:  814.708060303
# Epoch:  35
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  806.013326083
# ELL:  806.004922874
# KL:  0.00840344006365
# Epoch training time:  83.03287720680237
# Validation cost:  797.001722412
# Epoch:  36
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  790.904938299
# ELL:  790.89713956
# KL:  0.00779917852445
# Epoch training time:  82.77201676368713
# Validation cost:  789.825961914
# Epoch:  37
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  780.985299516
# ELL:  780.973959406
# KL:  0.0113410560109
# Epoch training time:  82.50908970832825
# Validation cost:  774.576466064
# Epoch:  38
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  773.070850275
# ELL:  773.059861839
# KL:  0.0109881010381
# Epoch training time:  82.98391437530518
# Validation cost:  769.940350342
# Epoch:  39
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  766.727992165
# ELL:  766.717768222
# KL:  0.0102233218063
# Epoch training time:  82.80150008201599
# Validation cost:  762.920808105
# Epoch:  40
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  761.956735507
# ELL:  761.946567494
# KL:  0.0101691463319
# Epoch training time:  82.84596300125122
# Validation cost:  760.452370605
# Epoch:  41
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  758.135346458
# ELL:  758.123067294
# KL:  0.0122803232887
# Epoch training time:  82.7132580280304
# Validation cost:  755.726982422
# Epoch:  42
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  755.362260853
# ELL:  755.351178422
# KL:  0.0110816273906
# Epoch training time:  82.90907955169678
# Validation cost:  754.232408447
# Epoch:  43
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  753.481468506
# ELL:  753.469532915
# KL:  0.0119354005293
# Epoch training time:  83.37359523773193
# Validation cost:  752.991326904
# Epoch:  44
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  751.948824796
# ELL:  751.938328857
# KL:  0.0104955056039
# Epoch training time:  82.79005646705627
# Validation cost:  751.485960693
# Epoch:  45
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  750.573558128
# ELL:  750.562359952
# KL:  0.0111986152692
# Epoch training time:  82.82339715957642
# Validation cost:  750.117607422
# Epoch:  46
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  749.748254284
# ELL:  749.738343395
# KL:  0.00991103562442
# Epoch training time:  83.00329256057739
# Validation cost:  749.302426758
# Epoch:  47
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  748.981429221
# ELL:  748.971496471
# KL:  0.00993437615308
# Epoch training time:  82.77409219741821
# Validation cost:  748.601253662
# Epoch:  48
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  748.522658802
# ELL:  748.51232555
# KL:  0.0103330231255
# Epoch training time:  82.72941136360168
# Validation cost:  748.176224365
# Epoch:  49
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  748.066656716
# ELL:  748.056297829
# KL:  0.0103577035124
# Epoch training time:  82.74961066246033
# Validation cost:  747.885252686
# Epoch:  50
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  747.817991278
# ELL:  747.809316961
# KL:  0.00867424320091
# Epoch training time:  83.44217777252197
# Validation cost:  747.638513184
# Epoch:  51
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  747.542540394
# ELL:  747.533160067
# KL:  0.00937991434878
# Epoch training time:  82.73244619369507
# Validation cost:  747.4025354
# Epoch:  52
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  747.345087225
# ELL:  747.335350231
# KL:  0.00973732243885
# Epoch training time:  82.88573718070984
# Validation cost:  747.30994873
# Epoch:  53
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  747.244421498
# ELL:  747.235626998
# KL:  0.00879312298515
# Epoch training time:  83.0090000629425
# Validation cost:  747.167509766
# Epoch:  54
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  747.144163374
# ELL:  747.134769398
# KL:  0.00939378819682
# Epoch training time:  82.87040662765503
# Validation cost:  747.070997314
# Epoch:  55
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  747.072770441
# ELL:  747.062335094
# KL:  0.0104349928011
# Epoch training time:  82.70219302177429
# Validation cost:  747.057091064
# Epoch:  56
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  747.026272084
# ELL:  747.015700351
# KL:  0.0105706266382
# Epoch training time:  82.7811062335968
# Validation cost:  746.980571289
# Epoch:  57
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  746.96821733
# ELL:  746.957184837
# KL:  0.0110321492499
# Epoch training time:  83.31109428405762
# Validation cost:  746.929134521
# Epoch:  58
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  746.913341508
# ELL:  746.879247936
# KL:  0.0340938248959
# Epoch training time:  82.7183403968811
# Validation cost:  746.377126465
# Epoch:  59
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  741.708740234
# ELL:  741.448131547
# KL:  0.260609512221
# Epoch training time:  82.90235686302185
# Validation cost:  736.940950928
# Epoch:  60
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  734.115012651
# ELL:  733.978632591
# KL:  0.136380545226
# Epoch training time:  83.16850352287292
# Validation cost:  731.623309326
# Epoch:  61
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  730.208773304
# ELL:  730.057656916
# KL:  0.151116757501
# Epoch training time:  82.87815618515015
# Validation cost:  729.00987793
# Epoch:  62
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  728.373067294
# ELL:  728.179828658
# KL:  0.193239391284
# Epoch training time:  82.78492045402527
# Validation cost:  727.713308105
# Epoch:  63
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  727.406203724
# ELL:  727.169252597
# KL:  0.236949405779
# Epoch training time:  82.74692845344543
# Validation cost:  727.125615234
# Epoch:  64
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  726.83644276
# ELL:  726.556062456
# KL:  0.280380690965
# Epoch training time:  83.2698130607605
# Validation cost:  726.638310547
# Epoch:  65
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  726.468554133
# ELL:  726.159846746
# KL:  0.308708307526
# Epoch training time:  82.72265696525574
# Validation cost:  726.337449951
# Epoch:  66
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  726.190784579
# ELL:  725.858357599
# KL:  0.332426728877
# Epoch training time:  82.97654461860657
# Validation cost:  725.982044678
# Epoch:  67
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  725.996276634
# ELL:  725.635163907
# KL:  0.361112073335
# Epoch training time:  83.06890225410461
# Validation cost:  725.883278809
# Epoch:  68
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  725.838390115
# ELL:  725.459586293
# KL:  0.378805102543
# Epoch training time:  82.93506932258606
# Validation cost:  725.701732178
# Epoch:  69
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  725.706672585
# ELL:  725.32022694
# KL:  0.386446001205
# Epoch training time:  82.55201077461243
# Validation cost:  725.521182861
# Epoch:  70
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  725.599892134
# ELL:  725.197987837
# KL:  0.401904802756
# Epoch training time:  82.57173705101013
# Validation cost:  725.515205078
# Epoch:  71
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  725.514864613
# ELL:  725.098772417
# KL:  0.41609197985
# Epoch training time:  83.57547068595886
# Validation cost:  725.406241455
# Epoch:  72
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  725.435590265
# ELL:  725.015548207
# KL:  0.420041566979
# Epoch training time:  82.71404314041138
# Validation cost:  725.249667969
# Epoch:  73
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  725.362552601
# ELL:  724.940848611
# KL:  0.421702475331
# Epoch training time:  82.97560238838196
# Validation cost:  725.189645996
# Epoch:  74
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  725.306629972
# ELL:  724.870155806
# KL:  0.436474270279
# Epoch training time:  85.22184944152832
# Validation cost:  725.280993652
# Epoch:  75
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  725.272597434
# ELL:  724.835019864
# KL:  0.437578384009
# Epoch training time:  82.92516946792603
# Validation cost:  725.194841309
# Epoch:  76
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  725.208455589
# ELL:  724.774656095
# KL:  0.433799339966
# Epoch training time:  82.6499593257904
# Validation cost:  725.042373047
# Epoch:  77
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  725.18809426
# ELL:  724.741358088
# KL:  0.446736139926
# Epoch training time:  82.704904794693
# Validation cost:  725.2890271
# Epoch:  78
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  725.149858731
# ELL:  724.705111195
# KL:  0.4447462795
# Epoch training time:  83.0987937450409
# Validation cost:  725.055059814
# Epoch:  79
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  725.114878263
# ELL:  724.665517911
# KL:  0.449362166145
# Epoch training time:  82.6710638999939
# Validation cost:  725.078751221
# Epoch:  80
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  725.091171875
# ELL:  724.638593972
# KL:  0.452578524026
# Epoch training time:  83.59520053863525
# Validation cost:  724.934619141
# Epoch:  81
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  725.069314076
# ELL:  724.61155107
# KL:  0.457763976617
# Epoch training time:  83.15788769721985
# Validation cost:  724.94189209
# Epoch:  82
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  725.043925115
# ELL:  724.587506658
# KL:  0.456418283636
# Epoch training time:  82.70942950248718
# Validation cost:  724.87289917
# Epoch:  83
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  725.033504861
# ELL:  724.565658736
# KL:  0.467846676653
# Epoch training time:  82.59346008300781
# Validation cost:  724.858494873
# Epoch:  84
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  725.006263428
# ELL:  724.53882757
# KL:  0.467435426929
# Epoch training time:  82.63554310798645
# Validation cost:  725.009204102
# Epoch:  85
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  724.983524059
# ELL:  724.515624445
# KL:  0.467900148522
# Epoch training time:  83.54696726799011
# Validation cost:  725.046275635
# Epoch:  86
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  724.962109042
# ELL:  724.491204057
# KL:  0.470904967135
# Epoch training time:  82.72343349456787
# Validation cost:  724.889077148
# Epoch:  87
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  724.958449374
# ELL:  724.473235307
# KL:  0.485215072849
# Epoch training time:  82.92738223075867
# Validation cost:  724.830756836
# Epoch:  88
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  724.922047563
# ELL:  724.442760898
# KL:  0.479286612922
# Epoch training time:  83.12080144882202
# Validation cost:  724.88618042
# Epoch:  89
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  724.912334761
# ELL:  724.43060791
# KL:  0.481727459106
# Epoch training time:  82.74681305885315
# Validation cost:  724.697587891
# Epoch:  90
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  724.889363348
# ELL:  724.404211759
# KL:  0.485151355917
# Epoch training time:  82.63381719589233
# Validation cost:  724.789351807
# Epoch:  91
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  724.878992032
# ELL:  724.388196911
# KL:  0.490794800303
# Epoch training time:  82.90731406211853
# Validation cost:  724.90107666
# Epoch:  92
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  724.863606179
# ELL:  724.37293113
# KL:  0.490675217889
# Epoch training time:  83.3030743598938
# Validation cost:  724.8690979
# Epoch:  93
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  724.848599964
# ELL:  724.35532049
# KL:  0.49327839147
# Epoch training time:  82.74627757072449
# Validation cost:  724.76559082
# Epoch:  94
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  724.836614768
# ELL:  724.336864125
# KL:  0.499750335758
# Epoch training time:  82.92564582824707
# Validation cost:  724.717296143
# Epoch:  95
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  724.818287908
# ELL:  724.322390803
# KL:  0.495895568349
# Epoch training time:  83.77924275398254
# Validation cost:  724.722961426
# Epoch:  96
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  724.80701416
# ELL:  724.304617032
# KL:  0.502396776026
# Epoch training time:  82.78306293487549
# Validation cost:  724.908875732
# Epoch:  97
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  724.794931752
# ELL:  724.298494096
# KL:  0.496437676495
# Epoch training time:  82.67125582695007
# Validation cost:  724.696437988
# Epoch:  98
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  724.779918213
# ELL:  724.277705078
# KL:  0.502212576649
# Epoch training time:  82.85504150390625
# Validation cost:  724.676334229
# Epoch:  99
# Progress:  10%
# Progress:  20%
# Progress:  30%
# Progress:  40%
# Progress:  50%
# Progress:  60%
# Progress:  70%
# Progress:  80%
# Progress:  90%
# Progress:  100%
# NELBO:  724.773183261
# ELL:  724.270933727
# KL:  0.502250437086
# Epoch training time:  82.92080664634705
# Validation cost:  724.768768311
# 724.7509210205078

# %%
pred, inter = vi.predict(np.reshape(mnist.test.images[2], [-1, 784]))

# %%
plt.imshow(np.reshape(mnist.test.images[2], (28, 28)))
plt.show()

# %%
plt.imshow(np.reshape(pred, (28, 28)))
plt.show()

# %%
for layer in range(5):
    print ("Layer", layer)
    
    for i in range(inter[layer].shape[-1]):
        img = np.reshape(inter[layer][:,:,:,i], [-1])
        dim = int(math.sqrt(img.shape[0]))
        plt.imshow(np.reshape(img, (dim, dim)))
        plt.show()
# Out:
# Layer 0
# Layer 1
# Layer 2
# Layer 3
# Layer 4

# %%
plt.imshow(np.reshape(mnist.test.images[0], (28, 28)))
plt.show()

# %%
plt.imshow(np.reshape(pred, (28, 28)))
plt.show()

# %%
for layer in range(5):
    print ("Layer", layer)
    
    for i in range(inter[layer].shape[-1]):
        img = np.reshape(inter[layer][:,:,:,i], [-1])
        dim = int(math.sqrt(img.shape[0]))
        plt.imshow(np.reshape(img, (dim, dim)))
        plt.show()
# Out:
# Layer 0
# Layer 1
# Layer 2
# Layer 3
# Layer 4

# %%
# 2_hidden: [784, 128, 64, 2, 64, 128, 784]
# vi.serialize('tmp/model_2_hidden.ckpt')
vi.serialize('mdump-conv-batch/model.ckpt')
# Out:
# Model saved in file: mdump-conv-batch/model.ckpt

# %%
vi = VariationalInference(n_datapoints, mc_samples, batch_size, constant_prior=False)
vi.restore('mdump-conv-batch/model.ckpt')
# Out:
# INFO:tensorflow:Restoring parameters from mdump-conv-batch/model.ckpt

# %%
def ll(Y, output):
    return np.sum(np.square(output - Y))

# %%
def plot_enc_dec():
    # Plot example reconstructions
    mean_img = np.mean(mnist.train.images, axis=0)
    n_examples = 10
    test_xs, _ = mnist.test.next_batch(n_examples)
    test_xs_norm = np.array([img - mean_img for img in test_xs])
    recon = vi.predict(test_xs_norm)
    print(recon.shape)
    fig, axs = plt.subplots(2, n_examples, figsize=(20, 4))
    for example_i in range(n_examples):
        error = ll(test_xs[example_i, :], recon[example_i, ...])
        print(error)
        
        axs[0][example_i].imshow(
            np.reshape(test_xs[example_i, :], (28, 28)))
        axs[1][example_i].imshow(
            np.reshape(
                np.reshape(recon[example_i, ...], (784,)) + mean_img,
                (28, 28)))
        plt.gray()
        axs[0][example_i].get_xaxis().set_visible(False)
        axs[0][example_i].get_yaxis().set_visible(False)
        axs[1][example_i].get_xaxis().set_visible(False)
        axs[1][example_i].get_yaxis().set_visible(False)
    plt.show()

# %% [markdown]
# ### Convolutional Autoencoder with Relu Activation

# %%
plot_enc_dec()
# Out:
# (10, 28, 28, 1)
# 3.83434
# 11.8171
# 6.72922
# 9.77896
# 10.0508
# 9.91503
# 10.847
# 7.78589
# 7.02046
# 11.9658

# %% [markdown]
# ### Convolutional Autoencoder with Sigmoid Activation

# %%
plot_enc_dec()
# Out:
# (10, 784)

# %% [markdown]
# ### Batch Norm

# %%
plot_enc_dec()
# Out:
# (10, 784)

# %%
plot_enc_dec()
# Out:
# (10, 784)
# 124449.0
# 112640.0
# 137545.0
# 115596.0
# 113895.0
# 108440.0
# 123931.0
# 129676.0
# 101638.0
# 122725.0

# %%
plot_enc_dec()
# Out:
# (10, 784)
# 65444.8
# 60504.8
# 65771.1
# 65357.9
# 69116.0
# 65683.4
# 62805.8
# 72424.5
# 62267.8
# 67114.9

# %% [markdown]
# ### Gaussian Likelihood

# %%
plot_enc_dec()
# Out:
# (10, 784)
# 32.8033
# 37.6063
# 35.7221
# 35.8901
# 35.8253
# 34.5572
# 36.8336
# 34.8909
# 36.3958
# 37.4163

# %% [markdown]
# ### Bernoulli

# %%
plot_enc_dec()
# Out:
# (10, 784)
# 222649.0
# 188148.0
# 275034.0
# 314183.0
# 254348.0
# 234593.0
# 228071.0
# 237095.0
# 241387.0
# 184269.0

# %%
plot_enc_dec()
# Out:
# (10, 784)
# 289588.0
# 314319.0
# 348304.0
# 359273.0
# 272975.0
# 298691.0
# 251000.0
# 308687.0
# 297575.0
# 339017.0

# %% [markdown]
# ### More weights

# %%
plot_enc_dec()
# Out:
# (10, 784)
# 174480.0
# 170904.0
# 173988.0
# 165579.0
# 165770.0
# 142119.0
# 193525.0
# 177957.0
# 215355.0
# 213933.0

# %%
plot_enc_dec()
# Out:
# (10, 784)
# 7.78009
# 6.10356
# 7.67744
# 5.47948
# 4.69815
# 4.54493
# 4.22648
# 6.69769
# 7.17801
# 7.92739

# %% [markdown]
# ### 10 samples

# %%
plot_enc_dec()
# Out:
# (10, 784)
# 37.2678
# 37.2486
# 34.229
# 40.5749
# 38.216
# 37.6495
# 36.3169
# 34.2932
# 39.5154
# 37.2319
